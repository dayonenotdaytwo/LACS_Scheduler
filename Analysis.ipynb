# %%
import pandas as pd
import numpy as np

# %%
# !ls *.pickle
# !ls Resources/18_19
# Out:
# CourseVals2.pickle  RoomVals2.pickle  UVals2.pickle  Xvals2.pickle
# Input1_Refactored.xlsx
# LP_Input.csv
# Preference Data Generation.ipynb
# preference_generation.py
# processed_preference_data.csv
# Proximity.csv
# School form - High School form responses.csv
# School form - Middle School form responses.csv
# Teacher_Template.csv

# %%
pd.read_pickle('Xvals2.pickle')
# Out:
# {(252, 36): 0.0,
#  (208, 66): 0.0,
#  (171, 86): 0.0,
#  (157, 23): 0.0,
#  (90, 42): 0.0,
#  (143, 36): 0.0,
#  (9, 0): 0.0,
#  (251, 85): 0.0,
#  (214, 91): 0.0,
#  (237, 90): 0.0,
#  (184, 26): 0.0,
#  (170, 21): 0.0,
#  (119, 90): 0.0,
#  (66, 66): 0.0,
#  (52, 17): 0.0,
#  (8, 87): 0.0,
#  (227, 45): 1.0,
#  (264, 33): 0.0,
#  (213, 2): 0.0,
#  (199, 51): 0.0,
#  (95, 98): 1.0,
#  (65, 11): 0.0,
#  (240, 63): 0.0,
#  (122, 63): 0.0,
#  (175, 43): 1.0,
#  (145, 12): 1.0,
#  (94, 57): 0.0,
#  (131, 49): 0.0,
#  (13, 13): 1.0,
#  (255, 78): 0.0,
#  (202, 70): 0.0,
#  (188, 21): 0.0,
#  (107, 79): 0.0,
#  (70, 81): 0.0,
#  (40, 4): 0.0,
#  (282, 65): 0.0,
#  (12, 90): 0.0,
#  (231, 38): 0.0,
#  (268, 44): 0.0,
#  (201, 23): 0.0,
#  (97, 70): 0.0,
#  (83, 23): 0.0,
#  (69, 40): 0.0,
#  (244, 2): 0.0,
#  (281, 56): 0.0,
#  (126, 42): 0.0,
#  (163, 60): 0.0,
#  (96, 9): 0.0,
#  (82, 52): 0.0,
#  (45, 64): 0.0,
#  (1, 58): 0.0,
#  (257, 80): 0.0,
#  (176, 0): 0.0,
#  (58, 44): 0.0,
# ...

# %%
import glob
import pickle

data = []
for pickle_file in glob.glob("*.pickle"):
    data.append(pickle.load(pickle_file))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b4dada901628> in <module>()
#       4 data = []
#       5 for pickle_file in glob.glob("*.pickle"):
# ----> 6     data.append(pickle.load(pickle_file))
#
# TypeError: file must have 'read' and 'readline' attributes

# %%
x = pd.read_pickle(glob.glob("*.pickle")[3])
xvals = pd.DataFrame(columns = preferences.columns, index = preferences.index)

for x_coord, y_coord in x.keys():
    xvals.iloc[x_coord, y_coord] = x[(x_coord,y_coord)]

# %%
xvals
# Out:
#     6th Grade Art 7th-8th Grade Art 8th Grade Science Adaptive PE  \
# 0             NaN                 0                 0           0
# 1             NaN                 0                 0           0
# 2             NaN                 0                 0           1
# 3             NaN                 0                 1           0
# 4             NaN                 0                 1           0
# 5             NaN                 0                 0           0
# 6             NaN                 0                 1           0
# 7             NaN                 0                 1           0
# 8             NaN                 0                 0           1
# 9             NaN                 0                 0           0
# 10            NaN                 0                 0           1
# 11            NaN                 0                 0           0
# 12            NaN                 0                 0           1
# ...

# %%
preferences = pd.read_csv("./Resources/18_19/processed_preference_data.csv",index_col=None)
