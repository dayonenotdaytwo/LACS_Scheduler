# %% [markdown]
# # Preference Analysis
# Analyzing preferences to understand which courses are popular, which times are popular, etc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Start by just reading in the data files. Both the raw preferences, as well as the binary manipulations

# %%
# Read Data from Analysis folder
raw = pd.read_excel("../Resources/fall2017data.xlsx", delimiter=',')

# Read preference matricies (from Justina)
first = pd.read_csv("../Resources/FirstChoiceBinary.csv")
second = pd.read_csv("../Resources/SecondChoiceBinary.csv")
third = pd.read_csv("../Resources/ThirdChoiceBinary.csv")

# %%
# Drop first column from first, second, and third
for df in [first, second, third]:
    df.drop(df.columns[0], axis=1, inplace = True)

# %% [markdown]
# ## Demand
# Here we will look at the demand for courses

# %%
# look at demand in first choice
first_sizes = {}
for course in first.columns:
    first_sizes[course] = first[course].sum()

# %%
# Get largest course
l = max(first_sizes, key=first_sizes.get)
s = first_sizes[l]
print(l, "is has the greatest demand of", s)
# Out:
# P4_Researchers (8th Grade SS) is has the greatest demand of 42

# %% [markdown]
# Next we will group by period

# %%
# Orgainze Courses by Periods
first_by_period = {}
for p in [1,2,3,4, 7,8]:
    period = "Period " + str(p)
    P = "P"+str(p)
    hold = {}
    for course in first_sizes:
        if course[0:2] == P:
            hold[course]= first_sizes[course]
    first_by_period[period] = hold

# %% [markdown]
# Lets orgainse the second and thir choices the same was as we did first choices above:

# %%
# get demand numbers
second_sizes = {}
for course in second.columns:
    second_sizes[course] = second[course].sum()
    
third_sizes = {}
for course in third.columns:
    third_sizes[course] = third[course].sum()

# %%
# Organize by period
second_by_period = {}
third_by_period = {}
for p in [1,2,3,4, 7,8]:
    period = "Period " + str(p)
    P = "P"+str(p)
    hold = {}
    for course in second_sizes:
        if course[0:2] == P:
            hold[course]= second_sizes[course]
    second_by_period[period] = hold
    hold = {}
    for course in third_sizes:
        if course[0:2] == P:
            hold[course] = third_sizes[course]
    third_by_period[period] = hold

# %%
# Print demandas by period and course, as well as build dictionary for plotting
tri_dict = {}
for p in [1,2,3,4,7,8]:
    period_dict = {}
    print("Period", p, "Demands:")
    print("Course", 39*" ", "First\t Second\t Third")
    P = "Period " + str(p)
    x = sorted(first_by_period[P].items(), key=lambda x:(x[1], x[0]), reverse=True)
    for c in x:
        course = c[0]
        fnum = first_by_period[P][course]
        snum = second_by_period[P][course]
        tnum = third_by_period[P][course]
        period_dict[course] = [fnum, snum, tnum] # add to period dict
        ws = 45 - len(course)
        print(course, ws*" ", fnum, "\t", snum, "\t", tnum)
    print("\n")
    tri_dict[P] = period_dict
# Out:
# Period 1 Demands:
# Course                                         First	 Second	 Third
# P1_MS Health                                   32 	 17 	 24
# P1_Other                                       31 	 38 	 40
# P1_Advanced Algebra & Trigonometry             26 	 17 	 25
# P1_HS PE                                       25 	 15 	 18
# P1_Evolutionary Biology                        20 	 24 	 19
# P1_7th-8th Grade Art                           20 	 14 	 17
# P1_Pre-Calculus                                18 	 13 	 16
# P1_Portfolio Photo                             16 	 19 	 17
# P1_French B                                    14 	 14 	 13
# P1_Middle School Social Studies with Dan       11 	 24 	 18
# P1_Facing History                              11 	 7 	 6
# P1_Constitutional Law/Government               10 	 15 	 16
# P1_Spanish A                                   7 	 13 	 9
# P1_HS English (TBA)                            5 	 16 	 7
# P1_Algebra A                                   0.0 	 0.0 	 1
#
#
# Period 2 Demands:
# Course                                         First	 Second	 Third
# P2_Other                                       27 	 35 	 41
# P2_Asia Studies                                25 	 23 	 26
# P2_MS Social Studies with Dan                  22 	 28 	 19
# P2_HS PE                                       22 	 20 	 17
# P2_Geology                                     22 	 23 	 23
# P2_Intermediate Algebra & Geometry             19 	 8 	 14
# P2_Intermediate Spanish                        18 	 7 	 13
# P2_Algebra A                                   18 	 11 	 17
# P2_HS English (TBA)                            15 	 15 	 16
# P2_8th Grade Science                           14 	 20 	 13
# P2_Spanish B                                   12 	 16 	 17
# P2_Intermediate French                         11 	 11 	 11
# P2_Facing History                              11 	 7 	 6
# P2_Drawing & Painting                          10 	 22 	 13
#
#
# Period 3 Demands:
# Course                                         First	 Second	 Third
# P3_Algebra B                                   35 	 19 	 16
# P3_HS Health                                   28 	 29 	 36
# P3_Other                                       24 	 24 	 35
# P3_Beginning Algebra and Geometry              22 	 15 	 16
# P3_American Studies/Global Perspective         21 	 12 	 6
# P3_Story of Life                               17 	 23 	 20
# P3_I Know Some Things                          17 	 17 	 17
# P3_Advanced Spanish                            17 	 15 	 15
# P3_Music Design                                12 	 9 	 7
# P3_Banned Books                                12 	 19 	 17
# P3_MS/HS PE                                    11 	 19 	 21
# P3_Studio Art                                  10 	 8 	 11
# P3_Intermediate Spanish                        10 	 15 	 10
# P3_Chemistry                                   10 	 22 	 19
#
#
# Period 4 Demands:
# Course                                         First	 Second	 Third
# P4_Researchers (8th Grade SS)                  42 	 20 	 20
# P4_MS/HS PE                                    29 	 26 	 28
# P4_Economics                                   28 	 29 	 30
# P4_Intro to Physics & Chemistry                24 	 13 	 22
# P4_Other                                       23 	 33 	 36
# P4_American Studies/Global Perspective         21 	 12 	 6
# P4_Community Service Class                     18 	 12 	 13
# P4_Intermediate Algebra and Geometry           13 	 25 	 16
# P4_Algebra A                                   12 	 18 	 10
# P4_Beginning Algebra and Trigonometry          11 	 17 	 14
# P4_MS Science (TBA)                            8 	 16 	 23
# P4_Advanced/In-Depth French                    8 	 10 	 10
# P4_Music, Myth, and Ritual                     6 	 10 	 15
# P4_Portfolio Art                               3 	 5 	 3
#
#
# Period 7 Demands:
# Course                                         First	 Second	 Third
# P7_Molecular Biology                           28 	 22 	 12
# P7_Other                                       26 	 27 	 36
# P7_African Studies                             23 	 18 	 28
# P7_Spanish B                                   22 	 19 	 17
# P7_Poet's Society                              21 	 25 	 20
# P7_Latin American Studies                      20 	 25 	 16
# P7_Anatomy & Physiology                        18 	 16 	 15
# P7_US History & Lit: The 20th Century          16 	 19 	 21
# P7_Celtic Band                                 15 	 14 	 10
# P7_Advanced Algebra & Trigonometry             13 	 19 	 12
# P7_Spanish A                                   12 	 5 	 9
# P7_MS/HS PE                                    11 	 19 	 19
# P7_English Seminar                             10 	 8 	 13
# P7_Video Production                            7 	 4 	 5
# P7_MS English & Social Studies (TBA)           2 	 4 	 12
# P7_Adaptive PE                                 2 	 2 	 1
#
#
# Period 8 Demands:
# Course                                         First	 Second	 Third
# P8_Dark Fiction                                34 	 24 	 27
# P8_Computer Literacy                           31 	 19 	 13
# P8_Other                                       25 	 25 	 30
# P8_MS Chemistry                                25 	 19 	 16
# P8_African Studies                             23 	 17 	 25
# P8_Latin American Studies                      20 	 26 	 18
# P8_US History & Lit: The 20th Century          17 	 20 	 21
# P8_HS PE                                       15 	 18 	 18
# P8_Probability & Statistics                    13 	 18 	 11
# P8_MS PE                                       11 	 3 	 6
# P8_In-Depth Spanish                            10 	 13 	 8
# P8_Algebra B                                   8 	 24 	 23
# P8_Ecology                                     7 	 4 	 10
# P8_French A                                    3 	 3 	 3
# P8_MS English & Social Studies                 2 	 3 	 12
# P8_Fiber Tech                                  1 	 6 	 2
# P8_Choir                                       1 	 4 	 2
# P8_PE                                          0.0 	 0.0 	 1

# %%
for p in [1,2,3,4,7,8]:
    x = tri_dict["Period " + str(p)]
    w = 0.22
    ind = np.arange(len(x))

    fig, ax = plt.subplots()

    b1 = ax.bar(ind, [y[0] for y in list(x.values())], w, color='r', alpha=.7)
    b2 = ax.bar(ind+w, [y[1] for y in list(x.values())], w,  color='b', alpha=.7)
    b3 = ax.bar(ind+2*w, [y[2] for y in list(x.values())],w,  color='g', alpha=.7)
    #negative = ax.bar(ind+3*w, [20 for y in range(len(x))], w)

    ax.set_xticks(ind + w/3)
    ax.set_xticklabels([y[3:] for y in list(x.keys())], rotation=90)

    ax.legend((b1[0], b2[0], b3[0]), ("First", "Second", "Third"))
    ax.set_title("Period " + str(p) +  " Demands")
    ax.autoscale_view()

    plt.show()
